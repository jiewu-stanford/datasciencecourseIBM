# %% [markdown]
# # A Consumer Business Comparison of New York and Toronto Based on the Top Venues of Their Key Boroughs

# %% [markdown]
# ## Abstract

# %% [markdown]
# The consumer business in New York and Toronto are studied and compared by analyzing the top venues of their key boroughs---Manhattan and Toronto borough.  The venue data are collected from Foursquare based on which the neighborhoods are clustered and the distinguishing categories of the venues are identified.  The analysis reflects a more developed and well-rounded consumer business in New York suggesting a better opportunity of starting up or expanding a consumer business in Toronto.  The insight obtained from this study should be useful to consumer business managers and/or investors exploring business opportunities in one of these two cities.

# %% [markdown]
# ## Methodology

# %% [markdown]
# The consumer business of the key boroughs of New York and Toronto are depicted using the venue location data retrieved from Foursquare.  The key boroughs chosen are Manhattan and Toronto borough respectively, the latter including east Toronto, west Toronto, central Toronto and downtown Toronto.  The choice of borough is partly based on the business districts, financial status and population of the borough compared to the other boroughs of the cities and partly for the sake of comparison---each borough contains roughly the same number of neighborhoods, 40 for Manhattan borough and 38 for Toronto borough.  To avoid verbose exposition in the following the word borough will be dropped and the two boroughs are simply referred to as Manhattan and Toronto (the latter should not be confused with Toronto as a city).

# %% [markdown]
# First a list of top 100 venues within 500 meters of the neighborhood's geographic coordinates (i.e.\ latitude and longitude) are collected from Foursquare for each neighborhood.  The rankings are based on the popularity of the venues among Foursquare users.  Giving that Foursquare is among the top three location data providers hosting over 60 million users the bias should be minimal.  Moreover the number of venues considered is 100 which should be sufficient to portraying the consumer business in the neighborhood.  The radius of the search is chosen according to the typical size of a neighborhood.  Therefore the choice of 500 meters should be appropriate to not only include the vast majority of the consumer business within a particular neighborhood but also prevent the analysis from being affected by the consumer business of nearby neighborhoods.

# %% [markdown]
# After the top 100 venues are collected for each neighborhood within a distance of 500 meters the categories of the venues are retrieved and consolidated to reveal the richness of the consumer business of New York and Toronto.  Then the top 10 categories of venues are identified for each neighborhood based on the mean of the frequency of their occurrence.  The purpose of the identification is to characterize the consumer business of the neighborhoods and group neighborhoods with similar characteristics.  The neighborhood clustering is determined using the k-means clustering algorithm where the coordinates of the neighborhoods are the mean of the occurrence frequency of the various venue categories.  Finally the neighborhoods are and plotted in the maps of the two cities and labeled with their cluster labels.  The distributions of the various neighborhood clusters of New York and Toronto are compared to reflect the distribution of the types of consumer business and the business opportunities are assessed.

# %% [markdown]
# ## Preparation for Analysis

# %% [markdown]
# #### Import necessary libraries and modules

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image
from IPython.core.display import HTML

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     cryptography-2.4.2         |   py36h1ba5d50_0         618 KB
#     openssl-1.1.1a             |    h14c3975_1000         4.0 MB  conda-forge
#     libarchive-3.3.3           |       h5d8350f_5         1.5 MB
#     grpcio-1.16.1              |   py36hf8bcb03_1         1.1 MB
#     geopy-1.18.1               |             py_0          51 KB  conda-forge
#     conda-4.6.2                |           py36_0         869 KB  conda-forge
#     libssh2-1.8.0              |                1         239 KB  conda-forge
#     python-3.6.8               |       h0371630_0        34.4 MB
#     ------------------------------------------------------------
#                                            Total:        42.7 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0                conda-forge
#
# The following packages will be UPDATED:
#
#     conda:         4.5.12-py36_1000         conda-forge --> 4.6.2-py36_0            conda-forge
#     cryptography:  2.3.1-py36hb7f436b_1000  conda-forge --> 2.4.2-py36h1ba5d50_0
#     curl:          7.63.0-h646f8bb_1000     conda-forge --> 7.63.0-hbc83047_1000
#     geopy:         1.11.0-py36_0            conda-forge --> 1.18.1-py_0             conda-forge
#     grpcio:        1.16.0-py36h4f00d22_1000 conda-forge --> 1.16.1-py36hf8bcb03_1
#     libcurl:       7.63.0-h01ee5af_1000     conda-forge --> 7.63.0-h20c2e04_1000
#     openssl:       1.0.2p-h14c3975_1002     conda-forge --> 1.1.1a-h14c3975_1000    conda-forge
#     pycurl:        7.43.0.2-py36hb7f436b_0              --> 7.43.0.2-py36h1ba5d50_0
#     python:        3.6.6-hd21baee_1003      conda-forge --> 3.6.8-h0371630_0
#     qt:            5.9.6-h8703b6f_2                     --> 5.9.7-h5867ecd_1
#
# The following packages will be DOWNGRADED:
#
#     krb5:          1.16.2-hc83ff2d_1000     conda-forge --> 1.16.1-h173b8e3_7
#     libarchive:    3.3.3-ha149a29_1000      conda-forge --> 3.3.3-h5d8350f_5
#     libssh2:       1.8.0-h1ad7b7a_1003      conda-forge --> 1.8.0-1                 conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# cryptography-2.4.2   | 618 KB    | ##################################### | 100%
# openssl-1.1.1a       | 4.0 MB    | ##################################### | 100%
# libarchive-3.3.3     | 1.5 MB    | ##################################### | 100%
# grpcio-1.16.1        | 1.1 MB    | ##################################### | 100%
# geopy-1.18.1         | 51 KB     | ##################################### | 100%
# conda-4.6.2          | 869 KB    | ##################################### | 100%
# libssh2-1.8.0        | 239 KB    | ##################################### | 100%
# python-3.6.8         | 34.4 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# #### Define custom functions for analysis

# %%
# get nearby venues via query to Foursquare
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# return the most common venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# #### Specify credentials to send query to Foursquare

# %%
CLIENT_ID = 'M1TDCQ3JGPKQ3UFHSISGBL3WUSH5PA5D125LMKBESYRYFCAW' # your Foursquare ID
CLIENT_SECRET = 'YL2X5EZYLFGFYEN4GXMUJ3DRYGQ0B32TYDDC4BI0UD2YYY0M' # your Foursquare Secret
VERSION = '20190203'
LIMIT = 100
radius = 500

# %% [markdown]
# #### Specify clustering parameters and colors for cluster plotting

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']
# create columns according to number of top venues
printcolumns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        printcolumns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        printcolumns.append('{}th Most Common Venue'.format(ind+1))

# %%
# set number of clusters
kclusters = 5
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
# rainbow = purple, blue, green, orange, red

# %% [markdown]
# ### Manhattan Neighborhood Analysis

# %% [markdown]
# #### Gather geographic data of New York

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset

# %%
with open('newyork_data.json') as newyork_json_data:
    newyork_data = json.load(newyork_json_data)
neighborhoods_data = newyork_data['features']

# %%
# instantiate the dataframe
newyork_nbhd = pd.DataFrame(['Borough', 'Neighborhood', 'Latitude', 'Longitude'])
for data in neighborhoods_data:
    borough = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
    
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    newyork_nbhd = newyork_nbhd.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
address = 'New York City, NY'
geolocator = Nominatim(user_agent="nyc_explorer")
location = geolocator.geocode(address)
newyork_lat = location.latitude
newyork_lng = location.longitude

# %% [markdown]
# #### Get the top 100 venues within 500 meters for each neighborhood and extract their categories

# %%
manhattan_data = newyork_nbhd[newyork_nbhd['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards

# %%
print('There are {} uniques categories.'.format(len(manhattan_venues['Venue Category'].unique())))
# Out:
# There are 331 uniques categories.

# %%
# one hot encoding
manhattan_onehot = pd.get_dummies(manhattan_venues[['Venue Category']], prefix="", prefix_sep="")
# add neighborhood column back to dataframe
manhattan_onehot['Neighborhood'] = manhattan_venues['Neighborhood']
# move neighborhood column to the first column
fixed_columns = [manhattan_onehot.columns[-1]] + list(manhattan_onehot.columns[:-1])
manhattan_onehot = manhattan_onehot[fixed_columns]
# normalize using the mean of the occurrence frequency of the venue categories
manhattan_grouped = manhattan_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# #### List the top 10 venue categories for each neighborhood

# %%
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=printcolumns)
neighborhoods_venues_sorted['Neighborhood'] = manhattan_grouped['Neighborhood']

for ind in np.arange(manhattan_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(manhattan_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# #### Cluster neighborhoods based on the mean frequency of occurrence of the venue categories

# %%
manhattan_grouped_clustering = manhattan_grouped.drop('Neighborhood', 1)
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(manhattan_grouped_clustering)
# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([0, 0, 0, 0, 0, 0, 0, 4, 0, 0, 0, 0, 0, 4, 0, 4, 0, 0, 0, 0, 4, 4,
#        1, 0, 3, 0, 0, 0, 4, 0, 2, 0, 0, 4, 0, 0, 0, 4, 0, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
manhattan_merged = manhattan_data
# add neighborhood names
manhattan_merged = manhattan_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %%
# create map
map_clusters = folium.Map(location=[newyork_lat, newyork_lng], zoom_start=11)

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### List the clusters

# %%
# cluster 1
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 0, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1   Manhattan               0    Chinese Restaurant       Bubble Tea Shop
# 6   Manhattan               0    African Restaurant    Chinese Restaurant
# 8   Manhattan               0    Italian Restaurant               Exhibit
# 9   Manhattan               0                   Gym                   Bar
# 10  Manhattan               0    Italian Restaurant           Coffee Shop
# 12  Manhattan               0    Italian Restaurant                   Bar
# 13  Manhattan               0               Theater  Gym / Fitness Center
# 14  Manhattan               0               Theater           Coffee Shop
# 15  Manhattan               0                 Hotel            Food Truck
# 16  Manhattan               0           Coffee Shop                 Hotel
# 17  Manhattan               0           Coffee Shop    Italian Restaurant
# 18  Manhattan               0    Italian Restaurant        Clothing Store
# 19  Manhattan               0        Ice Cream Shop                   Bar
# 20  Manhattan               0           Coffee Shop                  Café
# 21  Manhattan               0    Italian Restaurant                  Park
# 22  Manhattan               0                Bakery                  Café
# 23  Manhattan               0        Clothing Store              Boutique
# 24  Manhattan               0    Italian Restaurant        Cosmetics Shop
# 26  Manhattan               0           Coffee Shop             Bookstore
# 27  Manhattan               0    Italian Restaurant           Coffee Shop
# 28  Manhattan               0           Coffee Shop                  Park
# 29  Manhattan               0           Coffee Shop                 Hotel
# 30  Manhattan               0           Pizza Place        Cosmetics Shop
# 31  Manhattan               0    Italian Restaurant     French Restaurant
# 32  Manhattan               0  Gym / Fitness Center    Italian Restaurant
# 34  Manhattan               0  Gym / Fitness Center    Italian Restaurant
# 35  Manhattan               0    Italian Restaurant      Sushi Restaurant
# 38  Manhattan               0    Italian Restaurant           Yoga Studio
# 39  Manhattan               0           Coffee Shop    Italian Restaurant
#
#       3rd Most Common Venue   4th Most Common Venue  5th Most Common Venue  \
# 1       American Restaurant            Cocktail Bar  Vietnamese Restaurant
# 6       American Restaurant     Fried Chicken Joint      French Restaurant
# 8               Art Gallery             Coffee Shop                 Bakery
# 9        Italian Restaurant             Coffee Shop            Pizza Place
# 10         Sushi Restaurant    Gym / Fitness Center            Pizza Place
# 12              Coffee Shop                Wine Bar                 Bakery
# 13             Concert Hall                   Plaza     Italian Restaurant
# 14      American Restaurant      Italian Restaurant   Gym / Fitness Center
# 15              Coffee Shop              Steakhouse                Theater
# 16                      Spa      Italian Restaurant                    Gym
# 17           Ice Cream Shop               Nightclub                 Bakery
# 18        French Restaurant        Sushi Restaurant      Indian Restaurant
# 19                 Wine Bar            Cocktail Bar     Mexican Restaurant
# 20                   Bakery      Chinese Restaurant    Japanese Restaurant
# 21      American Restaurant                    Café                    Spa
# 22              Yoga Studio          Ice Cream Shop           Cocktail Bar
# 23            Women's Store              Shoe Store            Men's Store
# 24  New American Restaurant                Wine Bar              Jazz Club
# 26      American Restaurant                    Park             Food Truck
# 27                Wine Shop              Bagel Shop           Cocktail Bar
# 28                    Hotel               Wine Shop     Italian Restaurant
# 29                Wine Shop                     Bar                    Gym
# 30              Coffee Shop                    Café                    Gym
# 31             Cocktail Bar             Coffee Shop          Grocery Store
# 32                   Bakery       French Restaurant            Yoga Studio
# 34                Juice Bar  Furniture / Home Store      Indian Restaurant
# 35              Coffee Shop                Wine Bar                  Hotel
# 38     Gym / Fitness Center     American Restaurant         Clothing Store
# 39               Restaurant                    Café   Gym / Fitness Center
#
#        6th Most Common Venue      7th Most Common Venue  \
# 1         Dim Sum Restaurant          Hotpot Restaurant
# 6             Cosmetics Shop         Seafood Restaurant
# 8                  Juice Bar                      Hotel
# 9        Japanese Restaurant         Mexican Restaurant
# 10              Burger Joint                        Gym
# 12              Burger Joint          Indian Restaurant
# 13                      Café          French Restaurant
# 14                 Wine Shop                        Gym
# 15                       Spa        Sporting Goods Shop
# 16                       Bar        Japanese Restaurant
# 17       American Restaurant                    Theater
# 18                      Café         Seafood Restaurant
# 19          Ramen Restaurant                Pizza Place
# 20               Pizza Place  Latin American Restaurant
# 21               Coffee Shop                   Boutique
# 22        Chinese Restaurant         Salon / Barbershop
# 23  Mediterranean Restaurant         Italian Restaurant
# 24                 Gastropub                       Park
# 26             Deli / Bodega               Tennis Court
# 27                Restaurant     Thrift / Vintage Store
# 28             Shopping Mall              Women's Store
# 29                Steakhouse         Italian Restaurant
# 30                       Bar          French Restaurant
# 31        Mexican Restaurant                  Bookstore
# 32               Coffee Shop               Cocktail Bar
# 34              Dessert Shop        American Restaurant
# 35              Noodle House        Japanese Restaurant
# 38       Japanese Restaurant         Salon / Barbershop
# 39       American Restaurant                      Hotel
#
#             8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 1              Salon / Barbershop          Noodle House                 Bakery
# 6            Gym / Fitness Center                   Gym                    Bar
# 8               French Restaurant              Boutique   Gym / Fitness Center
# 9                Sushi Restaurant         Deli / Bodega                  Diner
# 10            Sporting Goods Shop                Bakery        Thai Restaurant
# 12  Vegetarian / Vegan Restaurant    Seafood Restaurant   Gym / Fitness Center
# 13          Performing Arts Venue                  Park            Opera House
# 14                          Hotel                   Spa         Sandwich Place
# 15                         Bakery        Clothing Store           Cocktail Bar
# 16              French Restaurant        Sandwich Place     Salon / Barbershop
# 17                    Art Gallery    Seafood Restaurant                  Hotel
# 18             Chinese Restaurant              Boutique           Burger Joint
# 19             Chinese Restaurant             Speakeasy    Filipino Restaurant
# 20                 Sandwich Place                  Park       Ramen Restaurant
# 21                       Wine Bar                   Gym       Greek Restaurant
# 22                 Sandwich Place    Seafood Restaurant        Bubble Tea Shop
# 23                    Art Gallery           Coffee Shop                 Bakery
# 24                         Bakery   American Restaurant      French Restaurant
# 26                   Burger Joint        Sandwich Place         Ice Cream Shop
# 27            American Restaurant         Grocery Store            Pizza Place
# 28                      BBQ Joint            Food Truck                    Gym
# 29                    Pizza Place            Food Truck     Falafel Restaurant
# 30                    Yoga Studio                   Spa              Bookstore
# 31            American Restaurant                 Hotel              Gift Shop
# 32                 Sandwich Place                   Spa    Sporting Goods Shop
# 34                         Bakery           Yoga Studio         Ice Cream Shop
# 35              Indian Restaurant            Steakhouse      French Restaurant
# 38                  Women's Store                   Gym                 Bakery
# 39                        Theater           Art Gallery                Dog Run

# %%
# cluster 2
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 1, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#      Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0  Manhattan               1        Discount Store           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0           Yoga Studio         Deli / Bodega       Supplement Shop
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0            Steakhouse         Shopping Mall            Shoe Store
#
#   9th Most Common Venue 10th Most Common Venue
# 0    Seafood Restaurant         Sandwich Place

# %%
# cluster 3
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 2, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 37  Manhattan               2                   Bar         Boat or Ferry
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 37                  Park            Playground      Basketball Court
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 37           Pet Service           Coffee Shop          Cocktail Bar
#
#    9th Most Common Venue 10th Most Common Venue
# 37     German Restaurant        Harbor / Marina

# %%
# cluster 4
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 3, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 33  Manhattan               3     Korean Restaurant        Cosmetics Shop
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 33                 Hotel             Hotel Bar   Japanese Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 33           Coffee Shop                Bakery          Cocktail Bar
#
#    9th Most Common Venue 10th Most Common Venue
# 33              Boutique   Gym / Fitness Center

# %%
# cluster 5
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 4, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2   Manhattan               4                  Café                Bakery
# 3   Manhattan               4    Mexican Restaurant                  Café
# 4   Manhattan               4    Mexican Restaurant           Coffee Shop
# 5   Manhattan               4         Deli / Bodega    Italian Restaurant
# 7   Manhattan               4    Mexican Restaurant                Bakery
# 11  Manhattan               4        Sandwich Place         Deli / Bodega
# 25  Manhattan               4           Pizza Place           Coffee Shop
# 36  Manhattan               4    Mexican Restaurant                  Park
#
#    3rd Most Common Venue      4th Most Common Venue  \
# 2      Mobile Phone Shop              Deli / Bodega
# 3                 Lounge                Pizza Place
# 4                   Café              Deli / Bodega
# 5     Mexican Restaurant         Seafood Restaurant
# 7          Deli / Bodega  Latin American Restaurant
# 11      Greek Restaurant                      Train
# 25           Yoga Studio                        Spa
# 36                  Café                Pizza Place
#
#         5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 2              Sandwich Place    Spanish Restaurant    Mexican Restaurant
# 3                    Wine Bar                Bakery         Deli / Bodega
# 4                 Pizza Place          Liquor Store          Cocktail Bar
# 5   Japanese Curry Restaurant      Sushi Restaurant          Liquor Store
# 7             Thai Restaurant                   Spa                  Café
# 11                Coffee Shop        Scenic Lookout                School
# 25        Szechuan Restaurant    Mexican Restaurant       Thai Restaurant
# 36           Greek Restaurant         Deli / Bodega                 Diner
#
#    8th Most Common Venue 9th Most Common Venue  \
# 2          Grocery Store                   Gym
# 3                   Park            Restaurant
# 4         Sandwich Place                School
# 5            Beer Garden    Falafel Restaurant
# 7             Taco Place    Chinese Restaurant
# 11                   Gym                  Park
# 25    Italian Restaurant         Deli / Bodega
# 36                 Hotel               Dog Run
#
#                       10th Most Common Venue
# 2                                Supermarket
# 3                         Frozen Yogurt Shop
# 4                         Chinese Restaurant
# 5                            Other Nightlife
# 7                                 Street Art
# 11  Residential Building (Apartment / Condo)
# 25                                       Bar
# 36                                       Spa

# %% [markdown]
# ### Toronto Neighborhood Analysis

# %% [markdown]
# #### Gather geographic data of Toronto

# %%
# %run ./WikiTableScrape.ipynb
# %run ./GeoCoord.ipynb
df = pd.read_csv('GeoPCodeTable.csv')
# Out:
# ['PostalCode', 'Borough', 'Neighbourhood']
# --2019-02-04 03:49:26--  http://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
# Resolving cocl.us (cocl.us)... 169.48.113.201
# Connecting to cocl.us (cocl.us)|169.48.113.201|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv [following]
# --2019-02-04 03:49:26--  https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
# Connecting to cocl.us (cocl.us)|169.48.113.201|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-02-04 03:49:26--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.27.197, 107.152.26.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.27.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-02-04 03:49:27--  https://ibm.ent.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.27.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.27.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!6yjPUr6rVHyp43oWnorLMGBEcAM-K3RIMLQAI20dnuXN2009n1pKMO4LIJwHwZ4uqjOGn5-gAlln6v8q_2_PHF2mueRzreIj8vPv5obB077NyG0OLJA2XISSPBzGXmG7gp2daYuk_qxvs51F7qOODkZi-M8nACR_dg6dehstW6ruaF5nyLrQBRSPj3SO0pL1Zt-0v5YQpZvgxoJKcciw3sy3L3cn-xTNbr11vr5AFow6i27BI_WzXLWkX32u-OoLroz9fDs84ojoPgyNrhfFQiT2iE_lP5f17sArLbieuntjk4ug9r1HrK1t644-qOxHMH9K2dIzxHshzSZex0eRZOjrZr232YAKWo8BOnaSCN_JBE13sdee4HSyEyPNi4X7eQXLPgJlax7W7pVLeESzB5GWBb2fbXZrIEiSdD8UWsFWmyarSI789OvI1RF1msbn0QYyldVZYvBMAGEdQ-OKOz00ckMGiEvHhRrI5k_sfAQEa6gwvijWY0xu1o-Yhgm_UUosvxDzXTipFV6C4JW5x0r6o9VHkTpeHbmuRSL4FpUq6cHPnN_K84x10PjZNVB2ZNHQGbjNeS-sTpuruENZ1JxLiScYSQcckr5PYAUB3prOurN-TwX2x7Ux8fYcbSEITWNv0Li9VR6zrwW4iYLmVMRYgLXps2DMEWwmQG1gqF0zENfFPOS5gkHtc52F-TUcPZoBY_58bps317N0N-tUEf3RwHOj5yi0A-PF5ec_-p6TNYqWDD4saCpLW4WC8goUqSahEACPUqv1jGGrpwPaC_tpsdKhsE3gY4dBVoLCbrZ-djtdcWS2UiCiB6PHNM2Qj2iH7QBGL7pdjU8ycU3fxJ3uQGoHN1D_FFpTElDV5LzHJpfYw9lHQ0ICT-7tAO5-O4mvgGH-6MelTBXDOWm2jlYKjkbDIq6myAXxgJNhzxaOF_giWFYzBb_J8igKntLS-KLdceqb_Xn0Yq_D-i20AJQLeUScUrR2VYStJlGepAf_Rrvd8YMzikWjeB1Pse3SKgY_l1_Ca-CGvv_7_qfmEgJAR2ngSxWidndUZSihROsIvp66aOnDUFdTNXkN_Qu2edGc_5sNo0EmnvUP_A1ZKtYHy-O_ASWDxI21Rn9T4JTNLRYsacBV2Szlv4giOD50IXkz7ioLoQoNpR3hbo7_eLzjvvogIJq_2nUWFwnhPQVSs4M1POliQnYqoQdOBwb5xq1QJPQYrKs8-LgT7GDtqRNEJdgbulmv6ngraiP4n1pKeOfrh9FPRBABtNkGeUHd6jyDrqSyPQhCq_QXk_YWnLLV6gla-wWikNV5NReCwRT0aLzwRFnDA9qEjdHeUS2OC7mJtMaKEGlKDocaQqUIJceVb8gT4f8rktxIBc31NB4B/download [following]
# --2019-02-04 03:49:28--  https://public.boxcloud.com/d/1/b1!6yjPUr6rVHyp43oWnorLMGBEcAM-K3RIMLQAI20dnuXN2009n1pKMO4LIJwHwZ4uqjOGn5-gAlln6v8q_2_PHF2mueRzreIj8vPv5obB077NyG0OLJA2XISSPBzGXmG7gp2daYuk_qxvs51F7qOODkZi-M8nACR_dg6dehstW6ruaF5nyLrQBRSPj3SO0pL1Zt-0v5YQpZvgxoJKcciw3sy3L3cn-xTNbr11vr5AFow6i27BI_WzXLWkX32u-OoLroz9fDs84ojoPgyNrhfFQiT2iE_lP5f17sArLbieuntjk4ug9r1HrK1t644-qOxHMH9K2dIzxHshzSZex0eRZOjrZr232YAKWo8BOnaSCN_JBE13sdee4HSyEyPNi4X7eQXLPgJlax7W7pVLeESzB5GWBb2fbXZrIEiSdD8UWsFWmyarSI789OvI1RF1msbn0QYyldVZYvBMAGEdQ-OKOz00ckMGiEvHhRrI5k_sfAQEa6gwvijWY0xu1o-Yhgm_UUosvxDzXTipFV6C4JW5x0r6o9VHkTpeHbmuRSL4FpUq6cHPnN_K84x10PjZNVB2ZNHQGbjNeS-sTpuruENZ1JxLiScYSQcckr5PYAUB3prOurN-TwX2x7Ux8fYcbSEITWNv0Li9VR6zrwW4iYLmVMRYgLXps2DMEWwmQG1gqF0zENfFPOS5gkHtc52F-TUcPZoBY_58bps317N0N-tUEf3RwHOj5yi0A-PF5ec_-p6TNYqWDD4saCpLW4WC8goUqSahEACPUqv1jGGrpwPaC_tpsdKhsE3gY4dBVoLCbrZ-djtdcWS2UiCiB6PHNM2Qj2iH7QBGL7pdjU8ycU3fxJ3uQGoHN1D_FFpTElDV5LzHJpfYw9lHQ0ICT-7tAO5-O4mvgGH-6MelTBXDOWm2jlYKjkbDIq6myAXxgJNhzxaOF_giWFYzBb_J8igKntLS-KLdceqb_Xn0Yq_D-i20AJQLeUScUrR2VYStJlGepAf_Rrvd8YMzikWjeB1Pse3SKgY_l1_Ca-CGvv_7_qfmEgJAR2ngSxWidndUZSihROsIvp66aOnDUFdTNXkN_Qu2edGc_5sNo0EmnvUP_A1ZKtYHy-O_ASWDxI21Rn9T4JTNLRYsacBV2Szlv4giOD50IXkz7ioLoQoNpR3hbo7_eLzjvvogIJq_2nUWFwnhPQVSs4M1POliQnYqoQdOBwb5xq1QJPQYrKs8-LgT7GDtqRNEJdgbulmv6ngraiP4n1pKeOfrh9FPRBABtNkGeUHd6jyDrqSyPQhCq_QXk_YWnLLV6gla-wWikNV5NReCwRT0aLzwRFnDA9qEjdHeUS2OC7mJtMaKEGlKDocaQqUIJceVb8gT4f8rktxIBc31NB4B/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.26.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.26.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_Coordinates.csv’
#
# Geospatial_Coordina 100%[=====================>]   2.82K  --.-KB/s   in 0s
#
# 2019-02-04 03:49:28 (42.5 MB/s) - ‘Geospatial_Coordinates.csv’ saved [2891/2891]
#
# ['PostalCode', 'Borough', 'Neighbourhood']

# %%
address = 'Toronto, Ontario'
geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
toronto_lat = location.latitude
toronto_lng = location.longitude

# %% [markdown]
# #### Get the top 100 venues within 500 meters for each neighborhood of Toronto and extract their categories

# %%
toronto_data = df[df['Borough'].str.contains("Toronto")]
toronto_data = toronto_data.reset_index(drop=True)
toronto_venues = getNearbyVenues(names=toronto_data['Neighbourhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
toronto_venues.rename(columns={'Neighborhood': 'Neighbourhood'}, inplace=True)
# Out:
# The Beaches
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront, Regent Park
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Business Reply Mail Processing Centre 969 Eastern

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 236 uniques categories.

# %% [markdown]
# #### List neighborhoods based on venue categories

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood']
# move neighborhood column to the first column
fixed_column = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_column]
# normalize using the mean of the occurrence frequency of the venue categories
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()

# %% [markdown]
# #### List the top 10 venue categories for each neighborhood

# %%
# create a new dataframe
neighborhood_venues_sorted = pd.DataFrame(columns=printcolumns)
neighborhood_venues_sorted.rename(columns={'Neighborhood': 'Neighbourhood'}, inplace=True)
neighborhood_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']
for ind in np.arange(toronto_grouped.shape[0]):
    neighborhood_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# #### Cluster neighborhoods based on the mean frequency of occurrence of the venue categories

# %%
toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)
kmeans.labels_
# Out:
# array([2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2,
#        1, 2, 0, 2, 2, 0, 4, 2, 2, 2, 2, 2, 2, 2, 1, 2], dtype=int32)

# %%
# add clustering labels
neighborhood_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_merged = toronto_data
# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhood_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

# %%
# create map
map_clusters = folium.Map(location=[toronto_lat, toronto_lng], zoom_start=11)

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### List the clusters

# %%
# cluster 1
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5,toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 8    Central Toronto               0            Playground
# 10  Downtown Toronto               0                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 8                   Park            Restaurant           Yoga Studio
# 10            Playground                 Trail           Yoga Studio
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 8                  Diner        Farmers Market    Falafel Restaurant
# 10                 Diner        Farmers Market    Falafel Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 8            Event Space  Ethiopian Restaurant      Electronics Store
# 10           Event Space  Ethiopian Restaurant      Electronics Store

# %%
# cluster 2
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5,toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 2      East Toronto               1        Sandwich Place
# 4   Central Toronto               1              Bus Line
# 37     East Toronto               1    Light Rail Station
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 2                   Park               Brewery            Steakhouse
# 4                   Park                  Lake    Dim Sum Restaurant
# 37           Yoga Studio                Garden           Pizza Place
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 2     Italian Restaurant     Food & Drink Shop     Fish & Chips Shop
# 4            Swim School           Yoga Studio  Fast Food Restaurant
# 37      Recording Studio            Restaurant         Burrito Place
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 2   Fast Food Restaurant          Liquor Store              Pet Store
# 4         Farmers Market    Falafel Restaurant            Event Space
# 37               Brewery            Skate Park         Farmers Market

# %%
# cluster 3
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5,toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels  1st Most Common Venue  \
# 0       East Toronto               2           Neighborhood
# 1       East Toronto               2       Greek Restaurant
# 3       East Toronto               2                   Café
# 5    Central Toronto               2                  Hotel
# 6    Central Toronto               2            Coffee Shop
# 7    Central Toronto               2           Dessert Shop
# 9    Central Toronto               2            Coffee Shop
# 11  Downtown Toronto               2             Restaurant
# 12  Downtown Toronto               2    Japanese Restaurant
# 13  Downtown Toronto               2            Coffee Shop
# 14  Downtown Toronto               2            Coffee Shop
# 15  Downtown Toronto               2            Coffee Shop
# 16  Downtown Toronto               2            Coffee Shop
# 17  Downtown Toronto               2            Coffee Shop
# 18  Downtown Toronto               2            Coffee Shop
# 19  Downtown Toronto               2            Coffee Shop
# 20  Downtown Toronto               2            Coffee Shop
# 21  Downtown Toronto               2            Coffee Shop
# 24   Central Toronto               2            Coffee Shop
# 25  Downtown Toronto               2                   Café
# 26  Downtown Toronto               2                    Bar
# 27  Downtown Toronto               2         Airport Lounge
# 28  Downtown Toronto               2            Coffee Shop
# 29  Downtown Toronto               2            Coffee Shop
# 30  Downtown Toronto               2                   Café
# 31      West Toronto               2               Pharmacy
# 32      West Toronto               2                    Bar
# 33      West Toronto               2  Performing Arts Venue
# 34      West Toronto               2     Mexican Restaurant
# 35      West Toronto               2         Breakfast Spot
# 36      West Toronto               2            Coffee Shop
#
#    2nd Most Common Venue   3rd Most Common Venue  \
# 0            Coffee Shop                     Pub
# 1            Coffee Shop          Ice Cream Shop
# 3            Coffee Shop             Yoga Studio
# 5                    Gym                    Park
# 6         Clothing Store     Sporting Goods Shop
# 7         Sandwich Place             Pizza Place
# 9                    Pub     American Restaurant
# 11           Coffee Shop                    Park
# 12      Sushi Restaurant             Coffee Shop
# 13                   Pub                    Park
# 14        Clothing Store                    Café
# 15            Restaurant                    Café
# 16          Cocktail Bar              Restaurant
# 17                  Café      Italian Restaurant
# 18                  Café              Steakhouse
# 19                 Hotel                Aquarium
# 20                 Hotel                    Café
# 21                  Café                   Hotel
# 24                  Café          Sandwich Place
# 25               Theater                  Bakery
# 26                  Café   Vietnamese Restaurant
# 27       Airport Service        Airport Terminal
# 28            Restaurant                    Café
# 29                  Café                   Hotel
# 30         Grocery Store                    Park
# 31           Supermarket          Discount Store
# 32           Men's Store              Restaurant
# 33           Coffee Shop                    Café
# 34                  Café  Furniture / Home Store
# 35             Gift Shop               Bookstore
# 36                  Café             Pizza Place
#
#             4th Most Common Venue      5th Most Common Venue  \
# 0                    Dance Studio             Discount Store
# 1                       Bookstore         Italian Restaurant
# 3             American Restaurant                     Bakery
# 5                  Breakfast Spot             Sandwich Place
# 6                     Yoga Studio                 Bagel Shop
# 7                     Coffee Shop                 Restaurant
# 9                Sushi Restaurant        Fried Chicken Joint
# 11                         Bakery                Pizza Place
# 12                        Gay Bar                 Restaurant
# 13                           Café                     Bakery
# 14                 Cosmetics Shop  Middle Eastern Restaurant
# 15                          Hotel             Clothing Store
# 16                            Pub             Farmers Market
# 17                   Burger Joint                        Bar
# 18            American Restaurant            Thai Restaurant
# 19                           Café                Pizza Place
# 20            American Restaurant                 Restaurant
# 21                     Restaurant        American Restaurant
# 24                    Pizza Place                   Pharmacy
# 25                      Bookstore                 Restaurant
# 26  Vegetarian / Vegan Restaurant                Coffee Shop
# 27                  Boat or Ferry            Harbor / Marina
# 28                            Pub         Seafood Restaurant
# 29                     Restaurant        American Restaurant
# 30              Convenience Store                  Nightclub
# 31                         Bakery       Gym / Fitness Center
# 32               Asian Restaurant                Coffee Shop
# 33                 Breakfast Spot              Grocery Store
# 34                           Park        Arts & Crafts Store
# 35                   Dessert Shop                 Restaurant
# 36                     Restaurant           Sushi Restaurant
#
#    6th Most Common Venue 7th Most Common Venue  8th Most Common Venue  \
# 0   Fast Food Restaurant        Farmers Market     Falafel Restaurant
# 1          Grocery Store               Brewery        Bubble Tea Shop
# 3     Italian Restaurant     Convenience Store        Coworking Space
# 5             Restaurant     Food & Drink Shop           Burger Joint
# 6         Cosmetics Shop  Gym / Fitness Center     Chinese Restaurant
# 7                   Café              Pharmacy     Seafood Restaurant
# 9             Bagel Shop            Sports Bar            Supermarket
# 11                  Café                   Pub     Italian Restaurant
# 12          Burger Joint             Gastropub                   Café
# 13        Breakfast Spot            Restaurant                Theater
# 14       Thai Restaurant                   Bar             Restaurant
# 15        Breakfast Spot          Cocktail Bar                   Park
# 16                Bakery              Beer Bar     Italian Restaurant
# 17       Bubble Tea Shop        Ice Cream Shop      Indian Restaurant
# 18        Clothing Store            Restaurant                  Hotel
# 19               Brewery    Italian Restaurant             Restaurant
# 20                   Gym         Deli / Bodega              Gastropub
# 21    Seafood Restaurant                Bakery             Steakhouse
# 24     Indian Restaurant        Cosmetics Shop                    Pub
# 25           Coffee Shop                   Bar    Japanese Restaurant
# 26                Bakery   Dumpling Restaurant     Mexican Restaurant
# 27               Airport    Airport Food Court           Airport Gate
# 28              Beer Bar          Cocktail Bar                  Hotel
# 29         Deli / Bodega    Seafood Restaurant       Asian Restaurant
# 30            Restaurant            Baby Store     Italian Restaurant
# 31           Pizza Place                  Pool            Music Venue
# 32                  Café          Cocktail Bar  Vietnamese Restaurant
# 33          Climbing Gym         Burrito Place   Gym / Fitness Center
# 34        Sandwich Place  Fast Food Restaurant              Bookstore
# 35         Movie Theater                  Bank     Italian Restaurant
# 36             Bookstore    Italian Restaurant                  Diner
#
#    9th Most Common Venue     10th Most Common Venue
# 0            Event Space       Ethiopian Restaurant
# 1             Restaurant       Caribbean Restaurant
# 3              Juice Bar    New American Restaurant
# 5            Yoga Studio        Dumpling Restaurant
# 6           Dessert Shop                      Diner
# 7       Sushi Restaurant         Italian Restaurant
# 9            Pizza Place         Light Rail Station
# 11                Market                 Beer Store
# 12  Fast Food Restaurant                Men's Store
# 13    Mexican Restaurant                 Shoe Store
# 14      Ramen Restaurant        Japanese Restaurant
# 15        Cosmetics Shop                     Bakery
# 16            Steakhouse         Seafood Restaurant
# 17       Thai Restaurant                        Spa
# 18                   Bar                     Bakery
# 19        Scenic Lookout                     Bakery
# 20    Italian Restaurant               Burger Joint
# 21                   Gym         Italian Restaurant
# 24          Burger Joint               Liquor Store
# 25             Nightclub               Noodle House
# 26    Chinese Restaurant         Dim Sum Restaurant
# 27      Sculpture Garden                      Plane
# 28    Italian Restaurant        Japanese Restaurant
# 29            Steakhouse                        Gym
# 30    Athletics & Sports                      Diner
# 31                  Café  Middle Eastern Restaurant
# 32                Bakery                Pizza Place
# 33               Stadium                        Bar
# 34           Flea Market  Cajun / Creole Restaurant
# 35               Dog Run                        Bar
# 36                   Pub               Dessert Shop

# %%
# cluster 4
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5,toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 23  Central Toronto               3                 Trail
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 23         Jewelry Store      Sushi Restaurant              Bus Line
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 23           Yoga Studio               Dog Run  Fast Food Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 23        Farmers Market    Falafel Restaurant            Event Space

# %%
# cluster 5
toronto_merged.loc[toronto_merged['Cluster Labels'] == 5, toronto_merged.columns[[1] + list(range(5,toronto_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Borough, Cluster Labels, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %% [markdown]
# #### Compare the venue categories of Manhattan and Toronto

# %%
to = toronto_venues['Venue Category'].unique().tolist()
to = set(to)

# %%
ma = manhattan_venues['Venue Category'].unique().tolist()
ma = set(ma)

# %%
print(to)
# Out:
# {'Butcher', 'Sporting Goods Shop', 'Creperie', 'Yoga Studio', 'Afghan Restaurant', 'Fountain', 'Recording Studio', 'Bistro', 'Skating Rink', 'Sculpture Garden', 'Wings Joint', 'Thai Restaurant', 'Pool', 'General Travel', 'Harbor / Marina', 'Dessert Shop', 'Pet Store', 'Breakfast Spot', 'Tanning Salon', 'Pharmacy', 'Deli / Bodega', 'Trail', 'Building', 'Salad Place', 'Plane', 'Mexican Restaurant', 'Strip Club', 'Irish Pub', 'Airport Lounge', 'Pub', 'Toy / Game Store', 'Fried Chicken Joint', 'Art Museum', 'Train Station', 'Food & Drink Shop', 'Airport Food Court', 'Burger Joint', 'Airport Service', 'Discount Store', 'Cajun / Creole Restaurant', 'Bubble Tea Shop', 'Doner Restaurant', 'Baby Store', 'Intersection', 'Dance Studio', 'Swim School', 'Food Truck', 'Beer Store', 'Scenic Lookout', 'Italian Restaurant', 'Playground', 'Arts & Crafts Store', 'Monument / Landmark', 'Garden Center', 'Jewish Restaurant', 'Vietnamese Restaurant', 'Taiwanese Restaurant', 'Brazilian Restaurant', 'Boat or Ferry', 'Music Store', 'Food Court', 'Hospital', 'Stationery Store', "Women's Store", 'Ramen Restaurant', 'Wine Bar', 'Museum', 'Portuguese Restaurant', 'Seafood Restaurant', 'Soup Place', 'Ethiopian Restaurant', 'Video Game Store', 'Japanese Restaurant', 'Hobby Shop', 'Molecular Gastronomy Restaurant', 'Office', 'Park', 'Gastropub', 'Bus Line', 'Airport Terminal', 'Flea Market', 'Record Shop', 'Restaurant', 'Pizza Place', 'Cuban Restaurant', 'Opera House', 'Coffee Shop', 'Skate Park', 'Dim Sum Restaurant', 'Snack Place', 'Antique Shop', 'Auto Workshop', 'Light Rail Station', 'Hotel', 'Neighborhood', 'Historic Site', 'Bookstore', 'Cocktail Bar', 'Steakhouse', 'College Rec Center', 'Supermarket', 'Stadium', 'Arepa Restaurant', 'Indian Restaurant', 'Convenience Store', 'Persian Restaurant', 'Concert Hall', 'Comic Shop', 'Performing Arts Venue', 'Coworking Space', 'Belgian Restaurant', 'Falafel Restaurant', 'Garden', 'Food', 'Department Store', 'Hotel Bar', 'Health & Beauty Service', 'History Museum', 'College Gym', 'Shoe Store', 'Indie Movie Theater', 'Electronics Store', 'Optical Shop', 'College Arts Building', 'Fish & Chips Shop', 'Chocolate Shop', 'Tailor Shop', 'Modern European Restaurant', 'Flower Shop', 'Event Space', 'Mediterranean Restaurant', 'Baseball Stadium', 'Juice Bar', 'Miscellaneous Shop', 'Sushi Restaurant', 'Sandwich Place', 'Diner', 'Bagel Shop', 'Comfort Food Restaurant', 'Gym', 'Salon / Barbershop', 'Spa', 'Latin American Restaurant', 'French Restaurant', 'Aquarium', 'Movie Theater', 'Adult Boutique', 'Airport Gate', 'Market', 'Jazz Club', 'Taco Place', 'American Restaurant', 'German Restaurant', 'Southern / Soul Food Restaurant', 'Farmers Market', 'Boutique', 'Sake Bar', 'Nightclub', 'Filipino Restaurant', 'Noodle House', 'Organic Grocery', 'Poutine Place', 'Basketball Stadium', 'Grocery Store', 'Gay Bar', 'Music Venue', 'Korean Restaurant', 'Fast Food Restaurant', 'Sports Bar', 'Smoke Shop', 'Cheese Shop', 'Donut Shop', 'Hookah Bar', 'Lingerie Store', 'Speakeasy', 'Fish Market', 'Airport', 'Beer Bar', 'Mac & Cheese Joint', 'Caribbean Restaurant', 'BBQ Joint', 'Church', 'Eastern European Restaurant', 'Beach', 'Asian Restaurant', 'Lounge', 'Bar', 'Gluten-free Restaurant', 'Poke Place', 'Bank', 'Art Gallery', 'Health Food Store', 'Climbing Gym', 'Gaming Cafe', 'Bakery', 'Middle Eastern Restaurant', 'Hotpot Restaurant', 'Rental Car Location', 'Fruit & Vegetable Store', 'Athletics & Sports', 'Jewelry Store', 'Piano Bar', 'Greek Restaurant', 'Malay Restaurant', 'Liquor Store', 'Lake', 'Theater', 'Smoothie Shop', 'Plaza', 'Hostel', 'Costume Shop', 'Gym / Fitness Center', 'Ice Cream Shop', 'Furniture / Home Store', 'Café', 'Vegetarian / Vegan Restaurant', 'New American Restaurant', 'Gourmet Shop', 'Shopping Mall', 'Martial Arts Dojo', 'Cosmetics Shop', 'Chinese Restaurant', 'Tapas Restaurant', 'Clothing Store', 'Dumpling Restaurant', 'Dog Run', "Men's Store", 'General Entertainment', 'Brewery', 'Cupcake Shop', 'Thrift / Vintage Store' ...

# %%
# common venue categories of Manhattan and Toronto
toma = to.intersection(ma)

# %%
len(toma)
# Out:
# 195

# %%
# venue categories of Toronto that is not found in Manhattan
tomiss = to - toma
print(tomiss)
# Out:
# {'Recording Studio', 'College Arts Building', 'Fish & Chips Shop', 'Hospital', 'Stationery Store', 'Baseball Stadium', 'General Travel', 'Fruit & Vegetable Store', 'Comfort Food Restaurant', 'Airport Terminal', 'Tanning Salon', 'Aquarium', 'Lake', 'Plane', 'Smoothie Shop', 'Airport Gate', 'Light Rail Station', 'Costume Shop', 'Neighborhood', 'Airport Lounge', 'Train Station', 'Airport Food Court', 'College Rec Center', 'Poutine Place', 'Basketball Stadium', 'Airport Service', 'Stadium', 'Cajun / Creole Restaurant', 'Doner Restaurant', 'Comic Shop', 'Intersection', 'Swim School', 'Food', 'Airport', 'Mac & Cheese Joint', 'Brewery', 'Home Service', 'Church', 'College Gym', 'Other Great Outdoors', 'Beach'}

# %%
# venue categories of Manhattan that is not found in Toronto
mamiss = ma - toma
print(mamiss)
# Out:
# {'Arcade', 'Sports Club', 'Pet Service', 'Szechuan Restaurant', 'Newsstand', 'Library', 'Bus Station', 'Pet Café', 'Exhibit', 'Lebanese Restaurant', 'Himalayan Restaurant', 'Australian Restaurant', 'Russian Restaurant', 'Train', 'Comedy Club', 'Venezuelan Restaurant', 'Video Store', 'Laundry Service', 'Spanish Restaurant', 'Veterinarian', 'General College & University', 'Rest Area', 'Tennis Court', 'Hardware Store', 'Temple', 'Boxing Gym', 'Camera Store', 'Stables', 'Caucasian Restaurant', 'Hot Dog Joint', 'Club House', 'Tennis Stadium', 'Pilates Studio', 'Scandinavian Restaurant', 'Board Shop', 'Design Studio', 'Peruvian Restaurant', 'Christmas Market', 'Resort', 'Swiss Restaurant', 'Other Nightlife', 'Austrian Restaurant', 'Animal Shelter', 'Bridal Shop', 'Massage Studio', 'Tech Startup', 'Paper / Office Supplies Store', 'Hawaiian Restaurant', 'Rock Club', 'Social Club', 'Non-Profit', 'Public Art', 'Basketball Court', 'College Bookstore', 'Moroccan Restaurant', 'Turkish Restaurant', 'Cambodian Restaurant', 'Herbs & Spices Store', 'Dry Cleaner', 'Music School', 'Paella Restaurant', 'Mobile Phone Shop', 'Shipping Store', 'Cafeteria', 'Karaoke Bar', 'Daycare', 'Mini Golf', 'Duty-free Shop', 'Roof Deck', 'Gym Pool', 'Tourist Information Center', 'Candy Store', 'Bike Trail', 'Bike Rental / Bike Share', 'Weight Loss Center', 'Indie Theater', 'Heliport', 'Recreation Center', 'Auditorium', 'Whisky Bar', 'Czech Restaurant', 'Kids Store', 'Frozen Yogurt Shop', 'Street Art', 'Watch Shop', 'Used Bookstore', 'Soba Restaurant', 'Drugstore', 'Tree', 'Supplement Shop', 'Tiki Bar', 'Tattoo Parlor', 'Japanese Curry Restaurant', 'Argentinian Restaurant', 'Spiritual Center', 'Gas Station', 'Beer Garden', 'Residential Building (Apartment / Condo)', 'Business Service', 'South American Restaurant', 'Volleyball Court', 'Wine Shop', 'High School', 'Dive Bar', 'Cultural Center', 'Nail Salon', 'Shanghai Restaurant', 'Accessories Store', 'Israeli Restaurant', 'Rock Climbing Spot', 'Waterfront', 'School', 'Outdoors & Recreation', 'Memorial Site', 'Pakistani Restaurant', 'Track', 'Kosher Restaurant', 'African Restaurant', 'College Academic Building', 'Udon Restaurant', 'North Indian Restaurant', 'Bed & Breakfast', 'Community Center', 'Cycle Studio', 'Pie Shop', 'River', 'Outdoor Sculpture', 'Medical Center', 'Golf Course', 'English Restaurant', 'Gymnastics Gym', 'College Theater', 'Bike Shop', 'Baseball Field', 'Theme Park Ride / Attraction', 'College Cafeteria'}
